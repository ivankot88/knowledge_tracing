# %%
# %%capture
# !pip install -r requirements.txt

# %%
# !wandb login
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
from main import main

# %%
import gc
import torch

torch.cuda.empty_cache()
gc.collect()
# Out:
# 2440

# %%
main(wandb_mode='online', is_test=False)
